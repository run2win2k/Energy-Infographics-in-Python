# %%
import pandas as pd
import numpy as np

# %%
new_2020 = pd.read_excel('Table_6_03_Aug2020.xlsx', skiprows=1 )
#Table_6_03 available at https://www.eia.gov/electricity/monthly/ (August 2020 release)
new_2020.head()
# Out:
#    Year  Month  Entity ID               Entity Name Plant Producer Type  \
# 0  2020    1.0    61012.0    AES Distributed Energy                 IPP
# 1  2020    1.0    63115.0           AZ Solar 1, LLC                 IPP
# 2  2020    1.0    63049.0         Cannon Garden LLC                 IPP
# 3  2020    1.0    63120.0         Cubera Solar, LLC                 IPP
# 4  2020    1.0    62801.0  DG Linden New Jersey LLC                 IPP
#
#                 Plant Name Plant State  Plant ID Generator ID  \
# 0  AES Tonawanda Solar LLC          NY   63161.0        TNWDA
# 1                   OE_AZ1          AZ   63349.0          AZ1
# 2      Cannon Garden Solar          MN   63252.0          CGS
# 3        Cubera Solar, LLC          NC   63346.0        PGR06
# 4              DG Infineum          NJ   62958.0        INFNM
#
#    \nNet Summer Capacity (MW)          Technology Energy Source Code  \
# 0                         2.0  Solar Photovoltaic                SUN
# ...

# %%
planned = pd.read_excel('Table_6_05_Aug2020.xlsx', skiprows=1 )
#Table_6_05 available at https://www.eia.gov/electricity/monthly/ (August 2020 release)
planned_2020 = planned[planned['Year'] == 2020]
planned_2020.head()
# Out:
#    Year  Month  Entity ID             Entity Name Plant Producer Type  \
# 0  2020    7.0    61012.0  AES Distributed Energy                 IPP
# 1  2020    7.0    61012.0  AES Distributed Energy                 IPP
# 2  2020    7.0    61012.0  AES Distributed Energy                 IPP
# 3  2020    7.0    61012.0  AES Distributed Energy                 IPP
# 4  2020    7.0    61012.0  AES Distributed Energy                 IPP
#
#                      Plant Name Plant State  Plant ID Generator ID  \
# 0        Allis Medina Solar LLC          NY   63129.0        ALLIS
# 1  Cronin Road Solar 1, LLC CSG          MA   63011.0         BESS
# 2         Finchville Solar, LLC          NY   62999.0        FINCH
# 3            Lane Ave Solar LLC          MA   63041.0        HANRA
# 4  Randall Solar Project Hybrid          MA   63475.0         BATT
#
#   \nNet Summer Capacity (MW)          Technology Energy Source Code  \
# 0                          5  Solar Photovoltaic                SUN
# ...

# %%
cols_list = planned_2020.columns.tolist()
cols_list
# Out:
# ['Year',
#  'Month',
#  'Entity ID',
#  'Entity Name',
#  'Plant Producer Type',
#  'Plant Name',
#  'Plant State',
#  'Plant ID',
#  'Generator ID',
#  '\nNet Summer Capacity (MW)',
#  'Technology',
#  'Energy Source Code',
#  'Prime Mover Code',
#  'Status',
#  '\nNameplate Capacity (MW)']

# %%
all_2020 = pd.concat([new_2020, planned_2020])
all_2020 = all_2020[cols_list]
all_2020.head()
# Out:
#    Year  Month  Entity ID               Entity Name Plant Producer Type  \
# 0  2020    1.0    61012.0    AES Distributed Energy                 IPP
# 1  2020    1.0    63115.0           AZ Solar 1, LLC                 IPP
# 2  2020    1.0    63049.0         Cannon Garden LLC                 IPP
# 3  2020    1.0    63120.0         Cubera Solar, LLC                 IPP
# 4  2020    1.0    62801.0  DG Linden New Jersey LLC                 IPP
#
#                 Plant Name Plant State  Plant ID Generator ID  \
# 0  AES Tonawanda Solar LLC          NY   63161.0        TNWDA
# 1                   OE_AZ1          AZ   63349.0          AZ1
# 2      Cannon Garden Solar          MN   63252.0          CGS
# 3        Cubera Solar, LLC          NC   63346.0        PGR06
# 4              DG Infineum          NJ   62958.0        INFNM
#
#   \nNet Summer Capacity (MW)          Technology Energy Source Code  \
# 0                          2  Solar Photovoltaic                SUN
# ...

# %%
new_2020.shape, planned_2020.shape, all_2020.shape
# Out:
# ((257, 13), (527, 15), (784, 15))

# %%
NY_2020 = all_2020[all_2020['Plant State'] =='NY']
NY_2020.shape
# Out:
# (58, 15)

# %%
NY_2020.groupby('Technology')['\nNet Summer Capacity (MW)'].sum()
# Out:
# Technology
# Batteries                             29.9
# Natural Gas Fired Combined Cycle    1016.1
# Onshore Wind Turbine                 204.0
# Petroleum Liquids                      1.5
# Solar Photovoltaic                   115.4
# Name: \nNet Summer Capacity (MW), dtype: float64

# %%
IA_2020 = all_2020[all_2020['Plant State'] =='IA']
IA_2020.shape
# Out:
# (20, 15)

# %%
IA_2020.groupby('Technology')['\nNet Summer Capacity (MW)'].sum()
# Out:
# Technology
# Conventional Hydroelectric      55.0
# Onshore Wind Turbine          1753.7
# Petroleum Liquids                6.7
# Solar Photovoltaic             102.6
# Name: \nNet Summer Capacity (MW), dtype: float64

# %%
inact = pd.read_excel('Table_6_04_Aug2020.xlsx', skiprows=1)
#Table_6_04 available at https://www.eia.gov/electricity/monthly/ (August 2020 release)
inact.head()
# Out:
#    Year  Month  Entity ID                   Entity Name Plant Producer Type  \
# 0  2020    1.0     3046.0   Duke Energy Progress - (NC)    Electric Utility
# 1  2020    1.0     3046.0   Duke Energy Progress - (NC)    Electric Utility
# 2  2020    1.0     9155.0  Inland Empire Energy Ctr LLC                 IPP
# 3  2020    1.0     9155.0  Inland Empire Energy Ctr LLC                 IPP
# 4  2020    1.0    15298.0             Talen Montana LLC                 IPP
#
#                     Plant Name Plant State  Plant ID Generator ID  \
# 0                    Asheville          NC    2706.0            1
# 1                    Asheville          NC    2706.0            2
# 2  Inland Empire Energy Center          CA   55853.0            1
# 3  Inland Empire Energy Center          CA   55853.0            2
# 4                     Colstrip          MT    6076.0            1
#
#    \nNet Summer Capacity (MW)                        Technology  \
# ...

# %%
inact[inact['Plant State']=='NY']
# Out:
#     Year  Month  Entity ID                     Entity Name  \
# 35  2020    3.0    22129.0       Somerset Operating Co LLC
# 37  2020    4.0     6027.0  Entergy Nuclear Indian Point 2
#
#    Plant Producer Type                 Plant Name Plant State  Plant ID  \
# 35                 IPP  Somerset Operating Co LLC          NY    6082.0
# 37                 IPP             Indian Point 2          NY    2497.0
#
#    Generator ID  \nNet Summer Capacity (MW)               Technology  \
# 35            1                       685.9  Conventional Steam Coal
# 37            2                      1016.1                  Nuclear
#
#    Energy Source Code Prime Mover Code
# 35                BIT               ST
# 37                NUC               ST

# %%
inact[inact['Plant State']=='MT']
# Out:
#    Year  Month  Entity ID        Entity Name Plant Producer Type Plant Name  \
# 4  2020    1.0    15298.0  Talen Montana LLC                 IPP   Colstrip
# 5  2020    1.0    15298.0  Talen Montana LLC                 IPP   Colstrip
#
#   Plant State  Plant ID Generator ID  \nNet Summer Capacity (MW)  \
# 4          MT    6076.0            1                       307.0
# 5          MT    6076.0            2                       307.0
#
#                 Technology Energy Source Code Prime Mover Code
# 4  Conventional Steam Coal                SUB               ST
# 5  Conventional Steam Coal                SUB               ST

# %%
planned_inact = pd.read_excel('Table_6_06_Aug2020.xlsx', skiprows=1)
#Table_6_06 available at https://www.eia.gov/electricity/monthly/ (August 2020 release)
planned_inact.head()
# Out:
#    Year Month  Entity ID                      Entity Name Plant Producer Type  \
# 0  2020     7     2848.0  California Institute-Technology          Commercial
# 1  2020     7    13756.0     Northern Indiana Pub Serv Co    Electric Utility
# 2  2020     7    20737.0      Willmar Municipal Utilities    Electric Utility
# 3  2020     7    20737.0      Willmar Municipal Utilities    Electric Utility
# 4  2020     8    11713.0          City of Marshall - (MI)    Electric Utility
#
#                            Plant Name Plant State  Plant ID Generator ID  \
# 0  California Institute of Technology          CA   10262.0         GEN6
# 1                              Bailly          IN     995.0           10
# 2                             Willmar          MN    2022.0            3
# 3                             Willmar          MN    2022.0          ST2
# 4                       Marshall (MI)          MI    1844.0          IC2
#
# ...

# %%
planned_inact[planned_inact['Technology']=='Nuclear']
# Out:
#      Year Month  Entity ID                      Entity Name  \
# 46   2020    12    55269.0  NextEra Energy Duane Arnold LLC
# 63   2021     4     6028.0   Entergy Nuclear Indian Point 3
# 114  2022     6    56192.0    Entergy Nuclear Palisades LLC
# 229  2024    11    14328.0       Pacific Gas & Electric Co.
# 283  2025     8    14328.0       Pacific Gas & Electric Co.
#
#     Plant Producer Type                  Plant Name Plant State  Plant ID  \
# 46                  IPP  Duane Arnold Energy Center          IA    1060.0
# 63                  IPP              Indian Point 3          NY    8907.0
# 114                 IPP                   Palisades          MI    1715.0
# 229    Electric Utility               Diablo Canyon          CA    6099.0
# 283    Electric Utility               Diablo Canyon          CA    6099.0
#
#     Generator ID  \nNet Summer Capacity (MW) Technology Energy Source Code  \
# 46             1                       601.4    Nuclear                NUC
# ...

# %%
planned_inact[planned_inact['Plant State']=='WA']
# Out:
#      Year Month  Entity ID                           Entity Name  \
# 45   2020    12    58341.0  McKinley Paper Co. - Washington Mill
# 49   2020    12    19099.0           TransAlta Centralia Gen LLC
# 304  2025    12    19099.0           TransAlta Centralia Gen LLC
#
#     Plant Producer Type                            Plant Name Plant State  \
# 45           Industrial  McKinley Paper Co. - Washington Mill          WA
# 49                  IPP        Transalta Centralia Generation          WA
# 304                 IPP        Transalta Centralia Generation          WA
#
#      Plant ID Generator ID  \nNet Summer Capacity (MW)  \
# 45    58352.0         G-11                        20.0
# 49     3845.0            1                       670.0
# 304    3845.0            2                       670.0
#
#                   Technology Energy Source Code Prime Mover Code
# 45   Wood/Wood Waste Biomass                WDS               ST
# ...

# %%
existing_plants = pd.read_excel('3_1_Generator_Y2019_Early_Release.xlsx', skiprows=2 )
#from https://www.eia.gov/electricity/data/eia860/
existing_plants.shape
# Out:
# (22701, 73)

# %%
existing_plants.head()
# Out:
#    Utility ID      Utility Name  Plant Code    Plant Name State      County  \
# 0         195  Alabama Power Co           2  Bankhead Dam    AL  Tuscaloosa
# 1         195  Alabama Power Co           3         Barry    AL      Mobile
# 2         195  Alabama Power Co           3         Barry    AL      Mobile
# 3         195  Alabama Power Co           3         Barry    AL      Mobile
# 4         195  Alabama Power Co           3         Barry    AL      Mobile
#
#   Generator ID                  Technology Prime Mover Unit Code  \
# 0            1  Conventional Hydroelectric          HY       NaN
# 1            1   Natural Gas Steam Turbine          ST       NaN
# 2            2   Natural Gas Steam Turbine          ST       NaN
# 3            4     Conventional Steam Coal          ST       NaN
# 4            5     Conventional Steam Coal          ST       NaN
#
#                   ...                 Planned Energy Source 1  \
# ...

# %%
existing_plants.columns
# Out:
# Index(['Utility ID', 'Utility Name', 'Plant Code', 'Plant Name', 'State',
#        'County', 'Generator ID', 'Technology', 'Prime Mover', 'Unit Code',
#        'Ownership', 'Duct Burners',
#        'Can Bypass Heat Recovery Steam Generator?',
#        'RTO/ISO LMP Node Designation',
#        'RTO/ISO Location Designation for Reporting Wholesale Sales Data to FERC',
#        'Nameplate Capacity (MW)', 'Nameplate Power Factor',
#        'Summer Capacity (MW)', 'Winter Capacity (MW)', 'Minimum Load (MW)',
#        'Uprate or Derate Completed During Year',
#        'Month Uprate or Derate Completed', 'Year Uprate or Derate Completed',
#        'Status', 'Synchronized to Transmission Grid', 'Operating Month',
#        'Operating Year', 'Planned Retirement Month', 'Planned Retirement Year',
#        'Associated with Combined Heat and Power System', 'Sector Name',
#        'Sector', 'Topping or Bottoming', 'Energy Source 1', 'Energy Source 2',
# ...

# %%
state_list = existing_plants.State.unique().tolist()
len(state_list)
# Out:
# 51

# %%
existing_plants.Technology.unique()
# Out:
# array(['Conventional Hydroelectric', 'Natural Gas Steam Turbine',
#        'Conventional Steam Coal', 'Natural Gas Fired Combined Cycle',
#        'Natural Gas Fired Combustion Turbine', 'Petroleum Liquids',
#        'Natural Gas Internal Combustion Engine', 'Nuclear',
#        'Onshore Wind Turbine', 'Solar Photovoltaic',
#        'Hydroelectric Pumped Storage', 'Geothermal', 'Landfill Gas',
#        'Batteries', 'Wood/Wood Waste Biomass',
#        'Coal Integrated Gasification Combined Cycle', 'Other Gases',
#        'Petroleum Coke', 'Municipal Solid Waste',
#        'Natural Gas with Compressed Air Storage', 'All Other',
#        'Other Waste Biomass', 'Solar Thermal without Energy Storage',
#        'Other Natural Gas', 'Solar Thermal with Energy Storage',
#        'Flywheels', 'Offshore Wind Turbine'], dtype=object)

# %%
coal = existing_plants[existing_plants['Technology'] == 'Conventional Steam Coal']
coal.shape
# Out:
# (666, 73)

# %%
coal_states = coal.State.unique().tolist()
len(coal_states)
# Out:
# 46

# %% [markdown]
# Four states (plus DC) have no coal plants as of end of 2019.

# %%
np.setdiff1d(state_list, coal_states)
# Out:
# array(['DC', 'MA', 'ME', 'RI', 'VT'],
#       dtype='<U2')

# %%
coal_plants = coal.groupby('State')['Plant Name'].value_counts()
coal_plants
# Out:
# State  Plant Name
# AK     Eielson AFB Central Heat & Power Plant    5
#        Utility Plants Section                    4
#        Aurora Energy LLC Chena                   3
#        University of Alaska Fairbanks            3
#        Healy                                     2
# AL     James H Miller Jr                         4
#        Charles R Lowman                          3
#        Barry                                     2
#        E C Gaston                                1
# AR     Independence Steam Electric Station       2
#        White Bluff                               2
#        Flint Creek                               1
#        John W Turk Jr Power Plant                1
#        Plum Point Energy Station                 1
# AZ     Springerville                             4
#        Cholla                                    3
#        Coronado                                  2
#        Apache Station                            1
# ...

# %%
hs['NY'].index.tolist()
# Out:
# ['RED-Rochester, LLC', 'Dunkirk Generating Plant', 'Somerset Operating Co LLC']

# %%
coal_counter = {}
for i in coal_states:
    coal_counter[i] = len(coal_plants[i])

coal_counter
# Out:
# {'AK': 5,
#  'AL': 4,
#  'AR': 5,
#  'AZ': 4,
#  'CA': 1,
#  'CO': 8,
#  'CT': 1,
#  'DE': 1,
#  'FL': 9,
#  'GA': 3,
#  'HI': 1,
#  'IA': 14,
#  'ID': 1,
#  'IL': 15,
#  'IN': 15,
#  'KS': 5,
#  'KY': 14,
#  'LA': 4,
#  'MD': 6,
#  'MI': 13,
#  'MN': 12,
#  'MO': 11,
#  'MS': 2,
#  'MT': 6,
#  'NC': 9,
#  'ND': 9,
#  'NE': 10,
#  'NH': 2,
#  'NJ': 2,
#  'NM': 3,
#  'NV': 2,
#  'NY': 3,
#  'OH': 12,
#  'OK': 6,
#  'OR': 1,
#  'PA': 18,
#  'SC': 4,
#  'SD': 1,
#  'TN': 5,
#  'TX': 16,
#  'UT': 5,
#  'VA': 6,
#  'WA': 1,
#  'WI': 10,
#  'WV': 10,
#  'WY': 12}

# %% [markdown]
# States with only a single coal generating station

# %%
singles = []

for key in coal_counter:
    if coal_counter[key] == 1:
        singles.append(key)
        
for i in singles:
    print(i, coal_plants[i].index[0])
# Out:
# SD Big Stone
# CT Bridgeport Station
# DE Indian River Generating Station
# ID Amalgamated Sugar Twin Falls
# WA Transalta Centralia Generation
# CA Argus Cogen Plant
# OR Boardman
# HI AES Hawaii
